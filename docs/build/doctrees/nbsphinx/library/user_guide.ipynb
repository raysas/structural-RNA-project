# %% [markdown]
# # User Guide

# %% [markdown]
# _this is a step by step user guide to the rna_score library_
#
# **Motivation:**
# The `rna_score` library is designed to provide a toolkit for RNA strcture prediction, particulalry aiming to create a suitable scoring function for RNA 3D structures. It offers a workflow to "train" a statistical potential based on known RNA structures, and then use this potential to score new RNA structures. The library is built to be modular and extensible, allowing users to customize various components of the scoring process.

# %% [markdown]
# ## Installation

# %% [markdown]
# The library can be installed via pip. You can install it directly from the GitHub repository using the following command:

# %%
# !pip install git+https://github.com/raysas/structural-RNA-project.git

# %%
import rna_score
rna_score.__version__
# Out:
# '0.1.0'

# %% [markdown]
# As the library is under the `lib` submodule, you can import it as follows for efficient access

# %%
import rna_score.lib as rna_score_lib

# %% [markdown]
# ## Downloading RNA Structures

# %% [markdown]
# To start training a scorign function, you first need a dataset of known RNA 3D structures. The library provides utilities to download RNA structures from public databases like the Protein Data Bank (PDB). You can use the `download_rna_structures` function to fetch RNA structures based on specific criteria, and use the `help()` function to get more information about its usage.
#
# We will start off by installing 1000 RNA structures from the PDB database.

# %%
rna_score_lib.download_rna_structures(max_structures=1000)
# Out:
# Searching for RNA structures in PDB...
# Found 1000 RNA structures
#
# Downloading 1000 structures in ['pdb', 'cif'] format(s)...
# Output directory: rna_structures
# Downloading:  61%|██████    | 1212/2000 [04:58<03:07,  4.21it/s, Success=1210, Failed=1]
# Download failed for 1vvj.pdb: HTTP 404 - Not Found
# Debug: Download failed for 1VVJ.pdb. See above for details.
# Download failed for 1vy4.pdb: HTTP 404 - Not Found
# Debug: Download failed for 1VY4.pdb. See above for details.
# Downloading:  61%|██████    | 1213/2000 [04:58<03:29,  3.75it/s, Success=1210, Failed=3]
# Download failed for 1vy5.pdb: HTTP 404 - Not Found
# Debug: Download failed for 1VY5.pdb. See above for details.
# Downloading:  61%|██████    | 1214/2000 [04:58<03:50,  3.41it/s, Success=1210, Failed=4]
# Download failed for 1vy6.pdb: HTTP 404 - Not Found
# Debug: Download failed for 1VY6.pdb. See above for details.
# Downloading:  61%|██████    | 1215/2000 [04:59<04:27,  2.93it/s, Success=1210, Failed=5]
# Download failed for 1vy7.pdb: HTTP 404 - Not Found
# Debug: Download failed for 1VY7.pdb. See above for details.
# Downloading: 100%|██████████| 2000/2000 [08:17<00:00,  4.02it/s, Success=1995, Failed=5]
# ==================================================
# Download Summary:
#   Total attempted: 2000
#   Successful: 1995
#   Failed: 5
#
# Failed downloads:
#   - 1VVJ.pdb
#   - 1VY4.pdb
#   - 1VY5.pdb
#   - 1VY6.pdb
#   - 1VY7.pdb
#
# Failed IDs saved to: rna_structures/failed_downloads.txt
# {'pdb_ids': ['124D',
#   '157D',
#   '165D',
#   '176D',
#   '17RA',
#   '1A1T',
#   '1A34',
#   '1A3M',
#   '1A4D',
#   '1A4T',
#   '1A51',
#   '1A60',
#   '1A9L',
#   '1A9N',
#   '1AC3',
#   '1AFX',
#   '1AJF',
#   '1AJL',
#   '1AJT',
#   '1AJU',
#   '1AKX',
#   '1AL5',
#   '1AM0',
#   '1ANR',
#   '1AQ3',
#   '1AQ4',
#   '1AQO',
#   '1ARJ',
#   '1ASY',
#   '1ASZ',
#   '1ATO',
#   '1ATV',
#   '1ATW',
#   '1AUD',
#   '1AV6',
#   '1B23',
#   '1B2M',
#   '1B36',
#   '1B7F',
#   '1BAU',
#   '1BGZ',
#   '1BIV',
#   '1BJ2',
#   '1BMV',
#   '1BN0',
#   '1BR3',
#   '1BVJ',
#   '1BYJ',
#   '1BYX',
#   '1BZ2',
#   '1BZ3',
#   '1BZT',
#   '1BZU',
#   '1C04',
#   '1C0A',
#   '1C0O',
#   '1C2Q',
#   '1C2W',
#   '1C2X',
#   '1C4L',
#   '1C9S',
#   '1CGM',
#   '1CQ5',
#   '1CQL',
#   '1CSL',
#   '1CVJ',
#   '1CWP',
#   '1CX5',
#   '1D0T',
#   '1D0U',
#   '1D4R',
#   '1D6K',
#   '1DDL',
#   '1DDY',
#   '1DFU',
#   '1DI2',
#   '1DK1',
#   '1DQF',
#   '1DQH',
#   '1DRR',
#   '1DRZ',
#   '1DUH',
#   '1DUL',
#   '1DUQ',
#   '1DV4',
#   '1DZ5',
#   '1E4P',
#   '1E7K',
#   '1E8O',
#   '1E8S',
#   '1E95',
#   '1EBQ',
#   '1EBR',
#   '1EBS',
#   '1EC6',
#   '1EFO',
#   '1EFS',
#   '1EFW',
#   '1EG0',
#   '1EGK',
#   '1EHT',
#   '1EHZ',
#   '1EI2',
#   '1EIY',
#   '1EJZ',
#   '1EKA',
#   '1EKD',
#   '1EKZ',
#   '1ELH',
#   '1EMI',
#   '1EQQ',
#   '1ESH',
#   '1ESY',
#   '1ET4',
#   '1ETF',
#   '1ETG',
#   '1EUQ',
#   '1EUY',
#   '1EVV',
#   '1EXD',
#   '1EXY',
#   '1F1T',
#   '1F27',
#   '1F5G',
#   '1F5H',
#   '1F5U',
#   '1F6U',
#   '1F6X',
#   '1F6Z',
#   '1F78',
#   '1F79',
#   '1F7F',
#   '1F7G',
#   '1F7H',
#   '1F7I',
#   '1F7U',
#   '1F7V',
#   '1F7Y',
#   '1F84',
#   '1F85',
#   '1F8V',
#   '1F9L',
#   '1FCW',
#   '1FEQ',
#   '1FEU',
#   '1FFK',
#   '1FFY',
#   '1FFZ',
#   '1FG0',
#   '1FHK',
#   '1FIR',
#   '1FIX',
#   '1FJE',
#   '1FJG',
#   '1FKA',
#   '1FL8',
#   '1FMN',
#   '1FNX',
#   '1FOQ',
#   '1FQZ',
#   '1FUF',
#   '1FXL',
#   '1FYO',
#   '1FYP',
#   '1G1X',
#   '1G2E',
#   '1G2J',
#   '1G3A',
#   '1G4Q',
#   '1G59',
#   '1G70',
#   '1GAX',
#   '1GID',
#   '1GRZ',
#   '1GSG',
#   '1GTF',
#   '1GTN',
#   '1GTR',
#   '1GTS',
#   '1GUC',
#   '1H0Q',
#   '1H1K',
#   '1H2C',
#   '1H2D',
#   '1H38',
#   '1H3E',
#   '1H4Q',
#   '1H4S',
#   '1HC8',
#   '1HG9',
#   '1HHW',
#   '1HHX',
#   '1HJI',
#   '1HLX',
#   '1HMH',
#   '1HNW',
#   '1HNX',
#   '1HNZ',
#   '1HQ1',
#   '1HR0',
#   '1HR2',
#   '1HS1',
#   '1HS2',
#   '1HS3',
#   '1HS4',
#   '1HS8',
#   '1HVU',
#   '1HWQ',
#   '1HYS',
#   '1I3X',
#   '1I3Y',
#   '1I46',
#   '1I4B',
#   '1I4C',
#   '1I5L',
#   '1I6H',
#   '1I6U',
#   '1I7J',
#   '1I94',
#   '1I95',
#   '1I96',
#   '1I97',
#   '1I9F',
#   '1I9K',
#   '1I9V',
#   '1I9X',
#   '1IBK',
#   '1IBL',
#   '1IBM',
#   '1IDV',
#   '1IE1',
#   '1IE2',
#   '1IK1',
#   '1IK5',
#   '1IKD',
#   '1IL2',
#   '1IVS',
#   '1J1U',
#   '1J2B',
#   '1J4Y',
#   '1J5A',
#   '1J5E',
#   '1J6S',
#   '1J7T',
#   '1J8G',
#   '1J9H',
#   '1JB8',
#   '1JBR',
#   '1JBS',
#   '1JBT',
#   '1JGO',
#   '1JGP',
#   '1JGQ',
#   '1JID',
#   '1JJ2',
#   '1JO7',
#   '1JOX',
#   '1JP0',
#   '1JTJ',
#   '1JTW',
#   '1JU1',
#   '1JU7',
#   '1JUR',
#   '1JWC',
#   '1JZC',
#   '1JZV',
#   '1JZX',
#   '1JZY',
#   '1JZZ',
#   '1K01',
#   '1K1G',
#   '1K2G',
#   '1K4A',
#   '1K4B',
#   '1K5I',
#   '1K6G',
#   '1K6H',
#   '1K73',
#   '1K8A',
#   '1K8S',
#   '1K8W',
#   '1K9M',
#   '1K9W',
#   '1KAJ',
#   '1KC8',
#   '1KD1',
#   '1KD3',
#   '1KD4',
#   '1KD5',
#   '1KFO',
#   '1KH6',
#   '1KIS',
#   '1KKA',
#   '1KKS',
#   '1KNZ',
#   '1KOC',
#   '1KOD',
#   '1KOG',
#   '1KOS',
#   '1KP7',
#   '1KPD',
#   '1KPY',
#   '1KPZ',
#   '1KQ2',
#   '1KQS',
#   '1KUQ',
#   '1KXK',
#   '1L1C',
#   '1L1W',
#   '1L2X',
#   '1L3D',
#   '1L3Z',
#   '1L8V',
#   '1L9A',
#   '1LAJ',
#   '1LC4',
#   '1LC6',
#   '1LDZ',
#   '1LMV',
#   '1LNG',
#   '1LNT',
#   '1LPW',
#   '1LS2',
#   '1LU3',
#   '1LUU',
#   '1LUX',
#   '1LVJ',
#   '1M1K',
#   '1M5K',
#   '1M5L',
#   '1M5O',
#   '1M5P',
#   '1M5V',
#   '1M82',
#   '1M8V',
#   '1M8W',
#   '1M8X',
#   '1M8Y',
#   '1M90',
#   '1MDG',
#   '1ME1',
#   '1MFJ',
#   '1MFK',
#   '1MFQ',
#   '1MFY',
#   '1MHK',
#   '1MIS',
#   '1MJ1',
#   '1MJI',
#   '1ML5',
#   '1MME',
#   '1MMS',
#   '1MNB',
#   '1MNX',
#   '1MSW',
#   '1MSY',
#   '1MT4',
#   '1MUV',
#   '1MV1',
#   '1MV2',
#   '1MV6',
#   '1MVR',
#   '1MWG',
#   '1MWL',
#   '1MY9',
#   '1MZP',
#   '1N1H',
#   '1N32',
#   '1N33',
#   '1N34',
#   '1N35',
#   '1N36',
#   '1N38',
#   '1N53',
#   '1N66',
#   '1N77',
#   '1N78',
#   '1N8R',
#   '1N8X',
#   '1NA2',
#   '1NAO',
#   '1NB7',
#   '1NBK',
#   '1NBR',
#   '1NBS',
#   '1NC0',
#   '1NEM',
#   '1NJI',
#   '1NJM',
#   '1NJN',
#   '1NJO',
#   '1NJP',
#   '1NKW',
#   '1NLC',
#   '1NTA',
#   '1NTB',
#   '1NTQ',
#   '1NTS',
#   '1NTT',
#   '1NUJ',
#   '1NUV',
#   '1NWX',
#   '1NWY',
#   '1NXR',
#   '1NYB',
#   '1NYI',
#   '1NZ1',
#   '1O0B',
#   '1O0C',
#   '1O15',
#   '1O3Z',
#   '1O9M',
#   '1OB2',
#   '1OB5',
#   '1OKF',
#   '1OLN',
#   '1OND',
#   '1OO7',
#   '1OOA',
#   '1OQ0',
#   '1OSU',
#   '1OSW',
#   '1OW9',
#   '1P5M',
#   '1P5N',
#   '1P5O',
#   '1P5P',
#   '1P6V',
#   '1P79',
#   '1P9X',
#   '1PBL',
#   '1PBM',
#   '1PBR',
#   '1PGL',
#   '1PJG',
#   '1PJO',
#   '1PJY',
#   '1PN7',
#   '1PN8',
#   '1PVO',
#   '1Q29',
#   '1Q2R',
#   '1Q2S',
#   '1Q75',
#   '1Q7Y',
#   '1Q81',
#   '1Q82',
#   '1Q86',
#   '1Q8N',
#   '1Q93',
#   '1Q96',
#   '1Q9A',
#   '1QA6',
#   '1QBP',
#   '1QC0',
#   '1QC8',
#   '1QCU',
#   '1QD3',
#   '1QD7',
#   '1QES',
#   '1QET',
#   '1QF6',
#   '1QFQ',
#   '1QLN',
#   '1QRS',
#   '1QRT',
#   '1QRU',
#   '1QTQ',
#   '1QU2',
#   '1QU3',
#   '1QVF',
#   '1QVG',
#   '1QWA',
#   '1QWB',
#   '1QZA',
#   '1QZB',
#   '1QZC',
#   '1QZW',
#   '1R2P',
#   '1R2W',
#   '1R2X',
#   '1R3E',
#   '1R3O',
#   '1R3X',
#   '1R4H',
#   '1R7W',
#   '1R7Z',
#   '1R9F',
#   '1R9S',
#   '1R9T',
#   '1RAU',
#   '1RAW',
#   '1RC7',
#   '1RFR',
#   '1RGO',
#   '1RHT',
#   '1RKJ',
#   '1RLG',
#   '1RMN',
#   '1RMV',
#   '1RNA',
#   '1RNG',
#   '1RNK',
#   '1ROQ',
#   '1RPU',
#   '1RRD',
#   '1RRR',
#   '1RXA',
#   '1RXB',
#   '1RY1',
#   '1S03',
#   '1S0V',
#   '1S2F',
#   '1S34',
#   '1S72',
#   '1S76',
#   '1S77',
#   '1S9L',
#   '1S9S',
#   '1SA9',
#   '1SAQ',
#   '1SCL',
#   '1SDR',
#   '1SDS',
#   '1SER',
#   '1SFO',
#   '1SI3',
#   '1SJ3',
#   '1SJ4',
#   '1SJF',
#   '1SLO',
#   '1SLP',
#   '1SM1',
#   '1SY4',
#   '1SYZ',
#   '1SZ1',
#   '1SZY',
#   '1T0D',
#   '1T0E',
#   '1T0K',
#   '1T1M',
#   '1T1O',
#   '1T28',
#   '1T2R',
#   '1T4L',
#   '1T4X',
#   '1TBK',
#   '1TFN',
#   '1TFW',
#   '1TFY',
#   '1TJZ',
#   '1TLR',
#   '1TN1',
#   '1TN2',
#   '1TOB',
#   '1TRA',
#   '1TRJ',
#   '1TTT',
#   '1TUT',
#   '1TXS',
#   '1U0B',
#   '1U1Y',
#   '1U2A',
#   '1U3K',
#   '1U63',
#   '1U6B',
#   '1U6P',
#   '1U9S',
#   '1ULL',
#   '1UN6',
#   '1UON',
#   '1URN',
#   '1UTD',
#   '1UTS',
#   '1UUD',
#   '1UUI',
#   '1UUU',
#   '1UVI',
#   '1UVJ',
#   '1UVK',
#   '1UVL',
#   '1UVM',
#   '1UVN',
#   '1VBX',
#   '1VBY',
#   '1VBZ',
#   '1VC0',
#   '1VC5',
#   '1VC6',
#   '1VFG',
#   '1VOP',
#   '1VQ4',
#   '1VQ5',
#   '1VQ6',
#   '1VQ7',
#   '1VQ8',
#   '1VQ9',
#   '1VQK',
#   '1VQL',
#   '1VQM',
#   '1VQN',
#   '1VQO',
#   '1VQP',
#   '1VTM',
#   '1VTQ',
#   '1VVJ',
#   '1VY4',
#   '1VY5',
#   '1VY6',
#   '1VY7',
#   '1W2B',
#   '1WKS',
#   '1WMQ',
#   '1WNE',
#   '1WPU',
#   '1WRQ',
#   '1WSU',
#   '1WTS',
#   '1WTT',
#   '1WVD',
#   '1WWD',
#   '1WWE',
#   '1WWF',
#   '1WWG',
#   '1WZ2',
#   '1X18',
#   '1X1L',
#   '1X8W',
#   '1X9C',
#   '1X9K',
#   '1XBP',
#   '1XHP',
#   '1XJR',
#   '1XMO',
#   '1XMQ',
#   '1XNQ',
#   '1XNR',
#   '1XOK',
#   '1XP7',
#   '1XPE',
#   '1XPF',
#   '1XPO',
#   '1XPR',
#   '1XPU',
#   '1XSG',
#   '1XSH',
#   '1XST',
#   '1XSU',
#   '1XV0',
#   '1XV6',
#   '1XWP',
#   '1XWU',
#   '1Y0Q',
#   '1Y1W',
#   '1Y1Y',
#   '1Y26',
#   '1Y27',
#   '1Y39',
#   '1Y3O',
#   '1Y3S',
#   '1Y69',
#   '1Y6S',
#   '1Y6T',
#   '1Y73',
#   '1Y77',
#   '1Y90',
#   '1Y95',
#   '1Y99',
#   '1YFG',
#   '1YFV',
#   '1YG3',
#   '1YG4',
#   '1YHQ',
#   '1YI2',
#   '1YIJ',
#   '1YIT',
#   '1YJ9',
#   '1YJN',
#   '1YJW',
#   '1YKQ',
#   '1YKV',
#   '1YLG',
#   '1YLS',
#   '1YMO',
#   '1YN1',
#   '1YN2',
#   '1YNC',
#   '1YNE',
#   '1YNG',
#   '1YRJ',
#   '1YSH',
#   '1YSV',
#   '1YTU',
#   '1YTY',
#   '1YVP',
#   '1YXP',
#   '1YY0',
#   '1YYK',
#   '1YYO',
#   '1YYW',
#   '1YZ9',
#   '1YZD',
#   '1Z2J',
#   '1Z30',
#   '1Z31',
#   '1Z43',
#   '1Z58',
#   '1Z79',
#   '1Z7F',
#   '1ZBH',
#   '1ZBI',
#   '1ZBL',
#   '1ZBN',
#   '1ZC5',
#   '1ZC8',
#   '1ZCI',
#   '1ZDH',
#   '1ZDI',
#   '1ZDJ',
#   '1ZDK',
#   '1ZE2',
#   '1ZEV',
#   '1ZFT',
#   '1ZFV',
#   '1ZFX',
#   '1ZH5',
#   '1ZHO',
#   '1ZIF',
#   '1ZIG',
#   '1ZIH',
#   '1ZJW',
#   '1ZL3',
#   '1ZN0',
#   '1ZN1',
#   '1ZO1',
#   '1ZO3',
#   '1ZSE',
#   '1ZX7',
#   '1ZZ5',
#   '1ZZN',
#   '205D',
#   '219D',
#   '21CC',
#   '21WE',
#   '21WJ',
#   '255D',
#   '259D',
#   '280D',
#   '283D',
#   '28SP',
#   '28SR',
#   '299D',
#   '2A04',
#   '2A0P',
#   '2A1R',
#   '2A2E',
#   '2A43',
#   '2A64',
#   '2A8V',
#   '2A9L',
#   '2A9X',
#   '2AAR',
#   '2AB4',
#   '2AD9',
#   '2ADB',
#   '2ADC',
#   '2ADT',
#   '2AGN',
#   '2AHT',
#   '2AKE',
#   '2ANN',
#   '2ANR',
#   '2AO5',
#   '2AP0',
#   '2AP5',
#   '2ASB',
#   '2ATW',
#   '2AU4',
#   '2AWE',
#   '2AWQ',
#   '2AZ0',
#   '2AZ2',
#   '2AZX',
#   '2B2D',
#   '2B2E',
#   '2B2G',
#   '2B3J',
#   '2B57',
#   '2B63',
#   '2B6G',
#   '2B7G',
#   '2B8R',
#   '2B8S',
#   '2BBV',
#   '2BCY',
#   '2BCZ',
#   '2BE0',
#   '2BEE',
#   '2BGG',
#   '2BH2',
#   '2BJ2',
#   '2BJ6',
#   '2BNY',
#   '2BQ5',
#   '2BS0',
#   '2BS1',
#   '2BTE',
#   '2BU1',
#   '2BX2',
#   '2BYT',
#   '2C06',
#   '2C0B',
#   '2C4Q',
#   '2C4R',
#   '2C4Y',
#   '2C4Z',
#   '2C50',
#   '2C51',
#   '2CD1',
#   '2CD3',
#   '2CD5',
#   '2CD6',
#   '2CJK',
#   '2CKY',
#   '2CSX',
#   '2CT8',
#   '2CV0',
#   '2CV1',
#   '2CV2',
#   '2CZJ',
#   '2D17',
#   '2D18',
#   '2D19',
#   '2D1A',
#   '2D1B',
#   '2D2K',
#   '2D2L',
#   '2D3O',
#   '2D6F',
#   '2DB3',
#   '2DD1',
#   '2DD2',
#   '2DD3',
#   '2DER',
#   '2DET',
#   '2DEU',
#   '2DLC',
#   '2DQO',
#   '2DQP',
#   '2DQQ',
#   '2DR2',
#   '2DR5',
#   '2DR7',
#   '2DR8',
#   '2DR9',
#   '2DRA',
#   '2DRB',
#   '2DU3',
#   '2DU4',
#   '2DU5',
#   '2DU6',
#   '2DVI',
#   '2DXI',
#   '2E2H',
#   '2E2I',
#   '2E2J',
#   '2E5L',
#   '2E9R',
#   '2E9T',
#   '2E9Z',
#   '2EC0',
#   '2EES',
#   '2EET',
#   '2EEU',
#   '2EEV',
#   '2EEW',
#   '2ERR',
#   '2ES5',
#   '2ESE',
#   '2ESI',
#   '2ESJ',
#   '2ET3',
#   '2ET4',
#   '2ET5',
#   '2ET8',
#   '2EUY',
#   '2EVY',
#   '2EZ6',
#   '2F4S',
#   '2F4T',
#   '2F4U',
#   '2F4V',
#   '2F4X',
#   '2F87',
#   '2F88',
#   '2F8K',
#   '2F8S',
#   '2F8T',
#   '2FCX',
#   '2FCY',
#   '2FCZ',
#   '2FD0',
#   '2FDT',
#   '2FEY',
#   '2FGP',
#   '2FK6',
#   '2FMT',
#   '2FQN',
#   '2FTC',
#   '2FY1',
#   '2FZ2',
#   '2G1G',
#   '2G1W',
#   '2G32',
#   '2G3S',
#   '2G4B',
#   '2G5K',
#   '2G8F',
#   '2G8H',
#   '2G8I',
#   '2G8K',
#   '2G8U',
#   '2G8V',
#   '2G8W',
#   '2G91',
#   '2G92',
#   '2G9C',
#   '2GBH',
#   '2GCS',
#   '2GCV',
#   '2GDI',
#   '2GIC',
#   '2GIO',
#   '2GIP',
#   '2GIS',
#   '2GJE',
#   '2GJW',
#   '2GM0',
#   '2GO5',
#   '2GPM',
#   '2GQ4',
#   '2GQ5',
#   '2GQ6',
#   '2GQ7',
#   '2GRB',
#   '2GRW',
#   '2GTT',
#   '2GUN',
#   '2GV3',
#   '2GV4',
#   '2GVO',
#   '2GXB',
#   '2H0S',
#   '2H0W',
#   '2H0X',
#   '2H0Z',
#   '2H1M',
#   '2H49',
#   '2HEM',
#   '2HGH',
#   '2HHH',
#   '2HNS',
#   '2HO6',
#   '2HO7',
#   '2HOJ',
#   '2HOK',
#   '2HOL',
#   '2HOM',
#   '2HOO',
#   '2HOP',
#   '2HT1',
#   '2HUA',
#   '2HVY',
#   '2HW8',
#   '2HYI',
#   '2I2Y',
#   '2I7E',
#   '2I7Z',
#   '2I82',
#   '2I91',
#   '2IHX',
#   '2IL9',
#   '2IRN',
#   '2IRO',
#   '2IX1',
#   '2IXY',
#   '2IXZ',
#   '2IY3',
#   '2IY5',
#   '2IZ8',
#   '2IZ9',
#   '2IZM',
#   '2IZN',
#   '2J0Q',
#   '2J0S',
#   '2J28',
#   '2J37',
#   '2JA5',
#   '2JA6',
#   '2JA7'],
#  'output_dir': PosixPath('rna_structures'),
#  'pdb_dir': PosixPath('rna_structures/pdb'),
#  'mmcif_dir': PosixPath('rna_structures/mmcif'),
#  'info': None}

# %% [markdown]
# ## Example 1: Default Scoring Function

# %% [markdown]
# ### Creating a Scorer object

# %% [markdown]
# The score function is encapsulated in a `RNAScorer` class, which manages the entire scoring process. You can create an instance of the `RNAScorer` class which will have the training performed on

# %%
vanilla_scorer = rna_score_lib.RNAScorer()

# %% [markdown]
# ### Extraction of distances

# %% [markdown]
# First starting by the extracting distances from structures in either `structures/pdb` or `structures/cif`, as it can read both formats.
# The default parameters for bins, atom_mode and ethod (histogram) are used when no parameters are provided, others can be specified as needed (see examples below).

# %%
vanilla_scorer.extract_distances(folder='rna_structures/pdb')
# Out:
# Searching for files in: rna_structures/pdb
# Found 995 files to process. Starting batch processing...
# Starting Parallel Processing (Atom Mode: C3')...
#   ...processed 10/995 structures
#   ...processed 20/995 structures
#   ...processed 30/995 structures
#   ...processed 40/995 structures
#   ...processed 50/995 structures
#   ...processed 60/995 structures
#   ...processed 70/995 structures
#   ...processed 80/995 structures
#   ...processed 100/995 structures
#   ...processed 120/995 structures
#   ...processed 130/995 structures
#   ...processed 140/995 structures
#   ...processed 150/995 structures
#   ...processed 160/995 structures
#   ...processed 170/995 structures
#   ...processed 180/995 structures
#   ...processed 190/995 structures
#   ...processed 200/995 structures
#   ...processed 210/995 structures
#   ...processed 220/995 structures
#   ...processed 230/995 structures
#   ...processed 240/995 structures
#   ...processed 250/995 structures
#   ...processed 260/995 structures
#   ...processed 270/995 structures
#   ...processed 280/995 structures
#   ...processed 290/995 structures
#   ...processed 300/995 structures
#   ...processed 310/995 structures
#   ...processed 320/995 structures
#   ...processed 330/995 structures
#   ...processed 340/995 structures
#   ...processed 350/995 structures
#   ...processed 360/995 structures
#   ...processed 370/995 structures
#   ...processed 380/995 structures
#   ...processed 390/995 structures
#   ...processed 400/995 structures
#   ...processed 410/995 structures
#   ...processed 420/995 structures
#   ...processed 430/995 structures
#   ...processed 440/995 structures
#   ...processed 450/995 structures
#   ...processed 460/995 structures
#   ...processed 470/995 structures
#   ...processed 490/995 structures
#   ...processed 500/995 structures
#   ...processed 510/995 structures
#   ...processed 520/995 structures
#   ...processed 530/995 structures
#   ...processed 540/995 structures
#   ...processed 550/995 structures
#   ...processed 560/995 structures
#   ...processed 570/995 structures
#   ...processed 580/995 structures
#   ...processed 590/995 structures
#   ...processed 600/995 structures
#   ...processed 610/995 structures
#   ...processed 620/995 structures
#   ...processed 630/995 structures
#   ...processed 640/995 structures
#   ...processed 660/995 structures
#   ...processed 670/995 structures
#   ...processed 680/995 structures
#   ...processed 690/995 structures
#   ...processed 700/995 structures
#   ...processed 720/995 structures
#   ...processed 730/995 structures
#   ...processed 740/995 structures
#   ...processed 750/995 structures
#   ...processed 760/995 structures
#   ...processed 770/995 structures
#   ...processed 780/995 structures
#   ...processed 790/995 structures
#   ...processed 800/995 structures
#   ...processed 810/995 structures
#   ...processed 820/995 structures
#   ...processed 830/995 structures
#   ...processed 840/995 structures
#   ...processed 850/995 structures
#   ...processed 860/995 structures
#   ...processed 870/995 structures
#   ...processed 880/995 structures
#   ...processed 890/995 structures
#   ...processed 900/995 structures
#   ...processed 910/995 structures
#   ...processed 920/995 structures
#   ...processed 930/995 structures
#   ...processed 940/995 structures
#   ...processed 950/995 structures
#   ...processed 960/995 structures
#   ...processed 970/995 structures
#   ...processed 980/995 structures
#   ...processed 990/995 structures
# Batch processing complete in 9.23 seconds.
#
# Writing results to 'dist_data/' (Method: HISTOGRAM)...
# Pipeline completed successfully.
# PosixPath('dist_data')

# %% [markdown]
# ### Training the Scoring Function

# %% [markdown]
# Here the training following the formula described in the documentation is performed, using the extracted distances to compute the statistical potential (v0.1.0).

# %%
vanilla_scorer.train_scoring()
# Out:
# PosixPath('training_output')

# %% [markdown]
# We can check the computation's output already performed are stored in the `RNAScorer` object for further use, like the histograms of each atom pair

# %%
vanilla_scorer.histograms['AA_histogram']
# Out:
#     count
# 0       0
# 1       0
# 2       0
# 3       3
# 4      51
# 5     469
# 6    2014
# 7    2524
# 8    3526
# 9    5021
# 10   7095
# 11  13628
# 12  13941
# 13  15734
# 14  20356
# 15  24836
# 16  26466
# 17  28893
# 18  32480
# 19  36622

# %% [markdown]
# ### Plotting the Scoring Function

# %% [markdown]
# An interactive view of the scorings accross teh different pairs can be visualized via the `plot_scores()` method of the `RNAScorer` class. If you're looking to save the plots, you can use `save_plot_scores()` method, specifying the desired output directory if needed (or will use default folder), as it will generate both png and html for each atom pair.

# %%
vanilla_scorer.plot_scores()

# %%
vanilla_scorer.save_plot_scores()
# Out:
# Plotting scoring profiles from training_output …
#   ✓ AA
#   ✓ AC
#   ✓ AG
#   ✓ AU
#   ✓ CC
#   ✓ CG
#   ✓ GG
#   ✓ CU
#   ✓ GU
#   ✓ UU
#
# ✓ Complete, plots saved in: plots
# 	plotly interactive plots in "plots/html"
# 	static png plots in "plots/png"
# PosixPath('plots')

# %% [markdown]
# ### Score a new RNA structure

# %% [markdown]
# At the end, this function has been trained to score a new RNA structure with the `score_structure()` method of the `RNAScorer` class. You can provide a path to a new RNA structure file (in PDB or CIF format), and the method will compute the score based on the trained statistical potential.

# %%
vanilla_scorer.score_structure(pdb_path='rna_structures/pdb/299d.pdb')
# Out:
# Loading scoring tables from training_output...
#   Loaded 8 base pair tables
#
# [1/1] Scoring: 299d.pdb...
#
# ============================================================
# SCORING RESULTS
# ============================================================
# Structure: 299d.pdb
# Number of interactions: 173
# Total Gibbs free energy estimate: 1.929
# ============================================================
#
# Detailed scores saved to: score_results.csv

# %% [markdown]
# ## Example 2
#
# Trying different parameters:
# * mmcif format
# * different atom mode
# * different binning strategy
# * different method (KDE)
# * different distance strategy

# %% [markdown]
# bold_scorer=RNAScorer()
